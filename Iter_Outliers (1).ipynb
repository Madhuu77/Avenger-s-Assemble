# %%
#Loading Data from Library and Converting it to Dataframe

# %%
from sklearn.datasets import load_diabetes
import pandas as pd
dia=load_diabetes()
col=dia.feature_names
df=pd.DataFrame(data=dia.data,columns=col)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# ...

# %%
#Plotting Box plot for Each feature using iterative statement
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.boxplot(y=k, data=df, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
#Findinng out Outliers using For Loop.
import numpy as np
for k,v in df.items():
    q1=v.quantile(.25)
    q2=v.quantile(.75)
    iqr=q2-q1
    v_col=v[(v<=q1-1.5*iqr)|(v>=q2+1.5*iqr)]
    perc=np.shape(v_col)[0]*100/np.shape(df)[0]
    print("Column %s Outliers perc:%.2f%%"%(k,perc))
# Out:
# Column age Outliers perc:0.00%
# Column sex Outliers perc:0.00%
# Column bmi Outliers perc:0.68%
# Column bp Outliers perc:0.00%
# Column s1 Outliers perc:1.81%
# Column s2 Outliers perc:1.58%
# Column s3 Outliers perc:1.58%
# Column s4 Outliers perc:0.90%
# Column s5 Outliers perc:0.90%
# Column s6 Outliers perc:2.04%
