# %% [markdown]
# Shallow Neural Network

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical
layers = tf.keras.layers
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# one-hot encode the labels
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
plt.figure(figsize=(10,8))
for i in range(1, 15):
    # image in ith position of gri
    plt.subplot(5, 5, i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    #plt.show()

# %%
model = tf.keras.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(20, activation='sigmoid'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', 
metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15, batch_size=32, 
validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7292 - loss: 1.1409 - val_accuracy: 0.9134 - val_loss: 0.3464
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 841us/step - accuracy: 0.9148 - loss: 0.3228 - val_accuracy: 0.9266 - val_loss: 0.2627
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 795us/step - accuracy: 0.9303 - loss: 0.2554 - val_accuracy: 0.9345 - val_loss: 0.2291
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 819us/step - accuracy: 0.9383 - loss: 0.2174 - val_accuracy: 0.9406 - val_loss: 0.2104
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 803us/step - accuracy: 0.9446 - loss: 0.1974 - val_accuracy: 0.9422 - val_loss: 0.1959
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 796us/step - accuracy: 0.9482 - loss: 0.1838 - val_accuracy: 0.9454 - val_loss: 0.1836
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 880us/step - accuracy: 0.9523 - loss: 0.1694 - val_accuracy: 0.9477 - val_loss: 0.1808
# Epoch 8/15
# ...

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('\n\nTest loss', loss)
print('Test accuracy', accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9493 - loss: 0.1662
#
#
# Test loss 0.14622630178928375
# Test accuracy 0.9556000232696533

# %% [markdown]
# Deep Neural Network

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical
from keras.datasets import fashion_mnist

# %%
layers = tf.keras.layers
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
print('X_train: ' + str(x_train.shape))
print('Y_train: ' + str(y_train.shape))
print('X_test: ' + str(x_test.shape))
print('Y_test: ' + str(y_test.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000, 10)
# X_test: (10000, 28, 28)
# Y_test: (10000, 10)

# %%
for i in range(1, 15):
    plt.subplot(5, 5, i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    #plt.show()

# %%
model = tf.keras.Sequential()

# %%
model.add(layers.Flatten())
model.add(layers.Dense(120, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15 , batch_size=32, 
validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.5036 - loss: 1.5652 - val_accuracy: 0.6459 - val_loss: 1.0075
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6735 - loss: 0.9088 - val_accuracy: 0.6687 - val_loss: 1.0079
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6830 - loss: 0.8588 - val_accuracy: 0.6712 - val_loss: 0.8248
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6890 - loss: 0.8126 - val_accuracy: 0.6989 - val_loss: 0.7795
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.6937 - loss: 0.7915 - val_accuracy: 0.6647 - val_loss: 0.8287
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7050 - loss: 0.7534 - val_accuracy: 0.7107 - val_loss: 0.7365
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7079 - loss: 0.7327 - val_accuracy: 0.7037 - val_loss: 0.7604
# Epoch 8/15
# ...

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('\n\nTest loss', loss)
print('Test accuracy', accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7311 - loss: 0.7055
#
#
# Test loss 0.7061355113983154
# Test accuracy 0.7329999804496765

# %% [markdown]
# Word-cloud

# %%
import matplotlib.pyplot as m
f=open("C:/Users/tejas/OneDrive/Documents/TT.txt")
text=f.read()

# %%
from wordcloud import WordCloud, STOPWORDS
stop_w=set(STOPWORDS)

# %%
wc=WordCloud(width=800,height=800,
background_color='tan',colormap='cubehelix',
stopwords=stop_w,
min_font_size=10).generate(text)

# %%
m.figure(figsize=(8,8),facecolor=None)
m.imshow(wc)
m.axis('off')
m.tight_layout(pad=0)
m.show()

# %% [markdown]
#  For the given sentence “Machine Learning is best platform. To group over selves”. Visualize the data for the better understanding and perform the following operations i )Word tokenization ii) Sentence tokenization iii) Dropping Stop word iv) Stemming v) Lemmatization

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string

# %%
# Input text
text = "Machine Learning is best platform. To group over selves."

# %%
# i) Sentence Tokenization
sentences = sent_tokenize(text)
print("Number of sentences:",len(sentences))
for i in range(len(sentences)):
    print("sentence:",i+1,"\n",sentences[i])
# Out:
# Number of sentences: 2
# sentence: 1
#  Machine Learning is best platform.
# sentence: 2
#  To group over selves.

# %%
# ii) Word Tokenization
words = word_tokenize(text)
print("Word Tokenization:", len(words))
print(words)
# Out:
# Word Tokenization: 11
# ['Machine', 'Learning', 'is', 'best', 'platform', '.', 'To', 'group', 'over', 'selves', '.']

# %%
# iii) Removing Stopwords
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.lower() not in stop_words and word not in string.punctuation]
print("\nWords after Stopwords Removal:", filtered_words)
# Out:
# Words after Stopwords Removal: ['Machine', 'Learning', 'best', 'platform', 'group', 'selves']

# %%
# iv) Stemming
ps = PorterStemmer()
stemmed_words = [ps.stem(i) for i in filtered_words]
print("\nStemmed Words:", stemmed_words)
# Out:
# Stemmed Words: ['machin', 'learn', 'best', 'platform', 'group', 'selv']

# %%
# v) Lemmatization
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(i) for i in filtered_words]
print("\nLemmatized Words:", lemmatized_words)
# Out:
# Lemmatized Words: ['Machine', 'Learning', 'best', 'platform', 'group', 'self']

# %% [markdown]
#  N-grams are defined as the combinationsof N Keywords together consider the given “The greatest glory in Living lies not in never falling but in raising every Lies”
# Generate bi grams for the above
# Generate Tri grams for the above

# %%
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

# %%
t=open("C:/Users/tejas/OneDrive/Documents/cie5.txt")
text=t.read()
w=word_tokenize(text)

# %%
print("Bi-Grams:\n\n",list(ngrams(w,2)))
print("\nTri-Grams:\n\n",list(ngrams(w,3)))
# Out:
# Bi-Grams:
#
#  [('The', 'greatest'), ('greatest', 'glory'), ('glory', 'in'), ('in', 'Living'), ('Living', 'lies'), ('lies', 'not'), ('not', 'in'), ('in', 'never'), ('never', 'falling'), ('falling', 'but'), ('but', 'in'), ('in', 'raising'), ('raising', 'every'), ('every', 'Lies')]
#
# Tri-Grams:
#
#  [('The', 'greatest', 'glory'), ('greatest', 'glory', 'in'), ('glory', 'in', 'Living'), ('in', 'Living', 'lies'), ('Living', 'lies', 'not'), ('lies', 'not', 'in'), ('not', 'in', 'never'), ('in', 'never', 'falling'), ('never', 'falling', 'but'), ('falling', 'but', 'in'), ('but', 'in', 'raising'), ('in', 'raising', 'every'), ('raising', 'every', 'Lies')]
