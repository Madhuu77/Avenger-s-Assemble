# %% [markdown]
# Shallow Neural Network

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical
layers = tf.keras.layers
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %%
# one-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
plt.figure(figsize=(10,8))
for i in range(1, 15):
    # image in ith position of gri
    plt.subplot(5, 5, i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
plt.show()

# %%
model = tf.keras.Sequential()
model.add(layers.Flatten())
model.add(layers.Dense(20, activation='sigmoid'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', 
metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15, batch_size=32, 
validation_data=(x_test, y_test))
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.7351 - loss: 1.1268 - val_accuracy: 0.9142 - val_loss: 0.3483
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9145 - loss: 0.3242 - val_accuracy: 0.9269 - val_loss: 0.2665
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9285 - loss: 0.2565 - val_accuracy: 0.9322 - val_loss: 0.2346
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9382 - loss: 0.2204 - val_accuracy: 0.9366 - val_loss: 0.2173
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9436 - loss: 0.2004 - val_accuracy: 0.9387 - val_loss: 0.2039
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9462 - loss: 0.1892 - val_accuracy: 0.9421 - val_loss: 0.1924
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9500 - loss: 0.1742 - val_accuracy: 0.9448 - val_loss: 0.1847
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9528 - loss: 0.1642 - val_accuracy: 0.9453 - val_loss: 0.1798
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9562 - loss: 0.1550 - val_accuracy: 0.9481 - val_loss: 0.1751
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9575 - loss: 0.1459 - val_accuracy: 0.9485 - val_loss: 0.1689
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9591 - loss: 0.1467 - val_accuracy: 0.9497 - val_loss: 0.1664
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9604 - loss: 0.1364 - val_accuracy: 0.9491 - val_loss: 0.1666
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9631 - loss: 0.1335 - val_accuracy: 0.9502 - val_loss: 0.1634
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9632 - loss: 0.1284 - val_accuracy: 0.9507 - val_loss: 0.1612
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9648 - loss: 0.1247 - val_accuracy: 0.9524 - val_loss: 0.1574

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('\n\nTest loss', loss)
print('Test accuracy', accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9470 - loss: 0.1727
#
#
# Test loss 0.15740273892879486
# Test accuracy 0.9524000287055969

# %% [markdown]
# Deep Neural Network

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.utils import to_categorical
from keras.datasets import fashion_mnist

# %%
layers = tf.keras.layers
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
print('X_train: ' + str(x_train.shape))
print('Y_train: ' + str(y_train.shape))
print('X_test: ' + str(x_test.shape))
print('Y_test: ' + str(x_test.shape))
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000, 10)
# X_test: (10000, 28, 28)
# Y_test: (10000, 28, 28)

# %%
for i in range(1, 15):
    plt.subplot(5, 5, i)
    plt.imshow(x_train[i], cmap=plt.get_cmap('gray'))
    plt.show()

# %%
model = Sequential()

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.8792 - loss: 0.3674
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8754 - loss: 0.3644
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8795 - loss: 0.3529
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8809 - loss: 0.3498
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8835 - loss: 0.3403
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8822 - loss: 0.3460
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8816 - loss: 0.3478
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8835 - loss: 0.3403
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8749 - loss: 0.3665
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8839 - loss: 0.3559
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8877 - loss: 0.3364
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8836 - loss: 0.3437
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8846 - loss: 0.3494
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8578 - loss: 0.3983
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8835 - loss: 0.3395

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('\n\nTest loss', loss)
print('Test accuracy', accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8686 - loss: 0.3977
#
#
# Test loss 0.4050425887107849
# Test accuracy 0.8657000064849854

# %% [markdown]
# Word-cloud

# %%
from wordcloud import WordCloud, STOPWORDS
stop_w=set(STOPWORDS)

# %%
wc=WordCloud(width=800,height=800,
background_color='tan',colormap='cubehelix',
stopwords=stop_w,
min_font_size=10).generate(text)

# %%
m.figure(figsize=(8,8),facecolor=None)
m.imshow(wc)
m.axis('off')
m.tight_layout(pad=0)
m.show()

# %% [markdown]
# TOKENIZATION

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

# %%
f=open("C:/Users/User/Documents/vk.txt")
text=f.read()
print(text)
# Out:
# Virat Kohli (Hindi pronunciation: [virat kohli] ; born 5 November 1988) is an Indian international cricketer who plays Test and ODI cricket for the Indian national team. A former captain in all formats of the game, Kohli retired from the T20I format following India's win at the 2024 T20 World Cup. He's a right-handed batsman and an occasional unorthodox right arm quick bowler. Kohli is regarded as one of the greatest batsmen of all time and the greatest in the modern era. He holds the highest IPL run-scorer record, ranks third in T20I, third in ODI, and stands the fourth-highest in international cricket.[4] He also holds the record for scoring the most centuries in ODI cricket and is second in the list of most international

# %%
sent=sent_tokenize(text)
print("Number of sentences:",len(sent))
for i in range(len(sent)):
     print("\nSentence:",i+1,"\n",sent[i])
# Out:
# Number of sentences: 6
#
# Sentence: 1
#  Virat Kohli (Hindi pronunciation: [virat kohli] ; born 5 November 1988) is an Indian international cricketer who plays Test and ODI cricket for the Indian national team.
#
# Sentence: 2
#  A former captain in all formats of the game, Kohli retired from the T20I format following India's win at the 2024 T20 World Cup.
#
# Sentence: 3
#  He's a right-handed batsman and an occasional unorthodox right arm quick bowler.
#
# Sentence: 4
#  Kohli is regarded as one of the greatest batsmen of all time and the greatest in the modern era.
#
# Sentence: 5
#  He holds the highest IPL run-scorer record, ranks third in T20I, third in ODI, and stands the fourth-highest in international cricket.
#
# Sentence: 6
#  [4] He also holds the record for scoring the most centuries in ODI cricket and is second in the list of most international

# %%
w=word_tokenize(text)
print("\nTotal Words:",len(w))
print(w)
# Out:
# Total Words: 144
# ['Virat', 'Kohli', '(', 'Hindi', 'pronunciation', ':', '[', 'virat', 'kohli', ']', ';', 'born', '5', 'November', '1988', ')', 'is', 'an', 'Indian', 'international', 'cricketer', 'who', 'plays', 'Test', 'and', 'ODI', 'cricket', 'for', 'the', 'Indian', 'national', 'team', '.', 'A', 'former', 'captain', 'in', 'all', 'formats', 'of', 'the', 'game', ',', 'Kohli', 'retired', 'from', 'the', 'T20I', 'format', 'following', 'India', "'s", 'win', 'at', 'the', '2024', 'T20', 'World', 'Cup', '.', 'He', "'s", 'a', 'right-handed', 'batsman', 'and', 'an', 'occasional', 'unorthodox', 'right', 'arm', 'quick', 'bowler', '.', 'Kohli', 'is', 'regarded', 'as', 'one', 'of', 'the', 'greatest', 'batsmen', 'of', 'all', 'time', 'and', 'the', 'greatest', 'in', 'the', 'modern', 'era', '.', 'He', 'holds', 'the', 'highest', 'IPL', 'run-scorer', 'record', ',', 'ranks', 'third', 'in', 'T20I', ',', 'third', 'in', 'ODI', ',', 'and', 'stands', 'the', 'fourth-highest', 'in', 'international', 'cricket', '.', '[', '4', ']', 'He', 'also', 'holds', 'the', 'record', 'for', 'scoring', 'the', 'most', 'centuries', 'in', 'ODI', 'cricket', 'and', 'is', 'second', 'in', 'the', 'list', 'of', 'most', 'international']

# %%
from nltk.util import ngrams
from nltk.tokenize import word_tokenize

# %%
f=open("C:/Users/User/Documents/vk.txt")
text=f.read()
w=word_tokenize(text)

# %%
print("Bi-Grams:\n\n",list(ngrams(w,2)))
print("\n\nTri-Grams:\n\n",list(ngrams(w,3)))
# Out:
# Bi-Grams:
#
#  [('Virat', 'Kohli'), ('Kohli', '('), ('(', 'Hindi'), ('Hindi', 'pronunciation'), ('pronunciation', ':'), (':', '['), ('[', 'virat'), ('virat', 'kohli'), ('kohli', ']'), (']', ';'), (';', 'born'), ('born', '5'), ('5', 'November'), ('November', '1988'), ('1988', ')'), (')', 'is'), ('is', 'an'), ('an', 'Indian'), ('Indian', 'international'), ('international', 'cricketer'), ('cricketer', 'who'), ('who', 'plays'), ('plays', 'Test'), ('Test', 'and'), ('and', 'ODI'), ('ODI', 'cricket'), ('cricket', 'for'), ('for', 'the'), ('the', 'Indian'), ('Indian', 'national'), ('national', 'team'), ('team', '.'), ('.', 'A'), ('A', 'former'), ('former', 'captain'), ('captain', 'in'), ('in', 'all'), ('all', 'formats'), ('formats', 'of'), ('of', 'the'), ('the', 'game'), ('game', ','), (',', 'Kohli'), ('Kohli', 'retired'), ('retired', 'from'), ('from', 'the'), ('the', 'T20I'), ('T20I', 'format'), ('format', 'following'), ('following', 'India'), ('India', "'s"), ("'s", 'win'), ('win', 'at'), ('at', 'the'), ('the', '2024'), ('2024', 'T20'), ('T20', 'World'), ('World', 'Cup'), ('Cup', '.'), ('.', 'He'), ('He', "'s"), ("'s", 'a'), ('a', 'right-handed'), ('right-handed', 'batsman'), ('batsman', 'and'), ('and', 'an'), ('an', 'occasional'), ('occasional', 'unorthodox'), ('unorthodox', 'right'), ('right', 'arm'), ('arm', 'quick'), ('quick', 'bowler'), ('bowler', '.'), ('.', 'Kohli'), ('Kohli', 'is'), ('is', 'regarded'), ('regarded', 'as'), ('as', 'one'), ('one', 'of'), ('of', 'the'), ('the', 'greatest'), ('greatest', 'batsmen'), ('batsmen', 'of'), ('of', 'all'), ('all', 'time'), ('time', 'and'), ('and', 'the'), ('the', 'greatest'), ('greatest', 'in'), ('in', 'the'), ('the', 'modern'), ('modern', 'era'), ('era', '.'), ('.', 'He'), ('He', 'holds'), ('holds', 'the'), ('the', 'highest'), ('highest', 'IPL'), ('IPL', 'run-scorer'), ('run-scorer', 'record'), ('record', ','), (',', 'ranks'), ('ranks', 'third'), ('third', 'in'), ('in', 'T20I'), ('T20I', ','), (',', 'third'), ('third', 'in'), ('in', 'ODI'), ('ODI', ','), (',', 'and'), ('and', 'stands'), ('stands', 'the'), ('the', 'fourth-highest'), ('fourth-highest', 'in'), ('in', 'international'), ('international', 'cricket'), ('cricket', '.'), ('.', '['), ('[', '4'), ('4', ']'), (']', 'He'), ('He', 'also'), ('also', 'holds'), ('holds', 'the'), ('the', 'record'), ('record', 'for'), ('for', 'scoring'), ('scoring', 'the'), ('the', 'most'), ('most', 'centuries'), ('centuries', 'in'), ('in', 'ODI'), ('ODI', 'cricket'), ('cricket', 'and'), ('and', 'is'), ('is', 'second'), ('second', 'in'), ('in', 'the'), ('the', 'list'), ('list', 'of'), ('of', 'most'), ('most', 'international')]
#
#
# Tri-Grams:
#
#  [('Virat', 'Kohli', '('), ('Kohli', '(', 'Hindi'), ('(', 'Hindi', 'pronunciation'), ('Hindi', 'pronunciation', ':'), ('pronunciation', ':', '['), (':', '[', 'virat'), ('[', 'virat', 'kohli'), ('virat', 'kohli', ']'), ('kohli', ']', ';'), (']', ';', 'born'), (';', 'born', '5'), ('born', '5', 'November'), ('5', 'November', '1988'), ('November', '1988', ')'), ('1988', ')', 'is'), (')', 'is', 'an'), ('is', 'an', 'Indian'), ('an', 'Indian', 'international'), ('Indian', 'international', 'cricketer'), ('international', 'cricketer', 'who'), ('cricketer', 'who', 'plays'), ('who', 'plays', 'Test'), ('plays', 'Test', 'and'), ('Test', 'and', 'ODI'), ('and', 'ODI', 'cricket'), ('ODI', 'cricket', 'for'), ('cricket', 'for', 'the'), ('for', 'the', 'Indian'), ('the', 'Indian', 'national'), ('Indian', 'national', 'team'), ('national', 'team', '.'), ('team', '.', 'A'), ('.', 'A', 'former'), ('A', 'former', 'captain'), ('former', 'captain', 'in'), ('captain', 'in', 'all'), ('in', 'all', 'formats'), ('all', 'formats', 'of'), ('formats', 'of', 'the'), ('of', 'the', 'game'), ('the', 'game', ','), ('game', ',', 'Kohli'), (',', 'Kohli', 'retired'), ('Kohli', 'retired', 'from'), ('retired', 'from', 'the'), ('from', 'the', 'T20I'), ('the', 'T20I', 'format'), ('T20I', 'format', 'following'), ('format', 'following', 'India'), ('following', 'India', "'s"), ('India', "'s", 'win'), ("'s", 'win', 'at'), ('win', 'at', 'the'), ('at', 'the', '2024'), ('the', '2024', 'T20'), ('2024', 'T20', 'World'), ('T20', 'World', 'Cup'), ('World', 'Cup', '.'), ('Cup', '.', 'He'), ('.', 'He', "'s"), ('He', "'s", 'a'), ("'s", 'a', 'right-handed'), ('a', 'right-handed', 'batsman'), ('right-handed', 'batsman', 'and'), ('batsman', 'and', 'an'), ('and', 'an', 'occasional'), ('an', 'occasional', 'unorthodox'), ('occasional', 'unorthodox', 'right'), ('unorthodox', 'right', 'arm'), ('right', 'arm', 'quick'), ('arm', 'quick', 'bowler'), ('quick', 'bowler', '.'), ('bowler', '.', 'Kohli'), ('.', 'Kohli', 'is'), ('Kohli', 'is', 'regarded'), ('is', 'regarded', 'as'), ('regarded', 'as', 'one'), ('as', 'one', 'of'), ('one', 'of', 'the'), ('of', 'the', 'greatest'), ('the', 'greatest', 'batsmen'), ('greatest', 'batsmen', 'of'), ('batsmen', 'of', 'all'), ('of', 'all', 'time'), ('all', 'time', 'and'), ('time', 'and', 'the'), ('and', 'the', 'greatest'), ('the', 'greatest', 'in'), ('greatest', 'in', 'the'), ('in', 'the', 'modern'), ('the', 'modern', 'era'), ('modern', 'era', '.'), ('era', '.', 'He'), ('.', 'He', 'holds'), ('He', 'holds', 'the'), ('holds', 'the', 'highest'), ('the', 'highest', 'IPL'), ('highest', 'IPL', 'run-scorer'), ('IPL', 'run-scorer', 'record'), ('run-scorer', 'record', ','), ('record', ',', 'ranks'), (',', 'ranks', 'third'), ('ranks', 'third', 'in'), ('third', 'in', 'T20I'), ('in', 'T20I', ','), ('T20I', ',', 'third'), (',', 'third', 'in'), ('third', 'in', 'ODI'), ('in', 'ODI', ','), ('ODI', ',', 'and'), (',', 'and', 'stands'), ('and', 'stands', 'the'), ('stands', 'the', 'fourth-highest'), ('the', 'fourth-highest', 'in'), ('fourth-highest', 'in', 'international'), ('in', 'international', 'cricket'), ('international', 'cricket', '.'), ('cricket', '.', '['), ('.', '[', '4'), ('[', '4', ']'), ('4', ']', 'He'), (']', 'He', 'also'), ('He', 'also', 'holds'), ('also', 'holds', 'the'), ('holds', 'the', 'record'), ('the', 'record', 'for'), ('record', 'for', 'scoring'), ('for', 'scoring', 'the'), ('scoring', 'the', 'most'), ('the', 'most', 'centuries'), ('most', 'centuries', 'in'), ('centuries', 'in', 'ODI'), ('in', 'ODI', 'cricket'), ('ODI', 'cricket', 'and'), ('cricket', 'and', 'is'), ('and', 'is', 'second'), ('is', 'second', 'in'), ('second', 'in', 'the'), ('in', 'the', 'list'), ('the', 'list', 'of'), ('list', 'of', 'most'), ('of', 'most', 'international')]

# %% [markdown]
# Frequency Distribution of Words

# %%
import matplotlib.pyplot as m
f=open("C:\\Users\\User\\Desktop\\RRR.txt")
text=f.read()
import pandas as p
import matplotlib.pyplot as m
from nltk.probability import FreqDist
freq=FreqDist(w)
print("Count of and word:",freq['and'])
freq=p.Series(dict(freq))
m.figure(figsize=(18,10))
freq.plot(kind='bar')
m.show()
# Out:
# Count of and word: 5

# %%
import matplotlib.pyplot as m
f=open("C:\\Users\\User\\Desktop\\RRR.txt")
text=f.read()
from wordcloud import WordCloud, STOPWORDS
stop_w=set(STOPWORDS)
wc=WordCloud(width=800,height=800,
background_color='black',colormap='plasma',
stopwords=stop_w,
min_font_size=10).generate(text)
m.figure(figsize=(8,8),facecolor=None)
m.imshow(wc)
m.axis('off')
m.tight_layout(pad=0)
m.show()

# %%
import re 
from nltk.tokenize import word_tokeni
