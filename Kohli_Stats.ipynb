# %%
#Import All the Required Packages for Performing Exploration,Preprocessing and Splitting Data
import pandas as pd
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading dataset using pandas Library of Virat Kohli Performance
df=pd.read_csv('C:/Users/91861/Downloads/Virat Kohli DataSet.csv')
df
# Out:
#      Runs   BF  4s  6s      SR  Pos Dismissal  Inns     Opposition  \
# 0      12   22   1   0   54.54  2.0       lbw     1    v Sri Lanka
# 1      37   67   6   0   55.22  2.0    caught     2    v Sri Lanka
# 2      25   38   4   0   65.78  1.0   run out     1    v Sri Lanka
# 3      54   66   7   0   81.81  1.0    bowled     1    v Sri Lanka
# 4      31   46   3   1   67.39  1.0       lbw     2    v Sri Lanka
# ..    ...  ...  ..  ..     ...  ...       ...   ...            ...
# 127    45   51   2   1   88.23  3.0    caught     2  v New Zealand
# 128    65   76   2   1   85.52  3.0    caught     1  v New Zealand
# 129   122  105   8   5  116.19  3.0    caught     2      v England
# 130     8    5   2   0  160.00  3.0    caught     1      v England
# 131    55   63   8   0   87.30  3.0    caught     2      v England
#
#             Ground Start Date
# 0         Dambulla  18-Aug-08
# 1         Dambulla  20-Aug-08
# 2    Colombo (RPS)  24-Aug-08
# 3    Colombo (RPS)  27-Aug-08
# ...

# %%
#transforming Data using LabelEncoder
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Dismissal']=le.fit_transform(df['Dismissal'])
df['Opposition']=le.fit_transform(df['Opposition'])
df['Ground']=le.fit_transform(df['Ground'])
df['Start Date']=le.fit_transform(df['Start Date'])

# %%
#Finding Out the null values 
df.isna().sum()
# Out:
# Runs          0
# BF            0
# 4s            0
# 6s            0
# SR            0
# Pos           0
# Dismissal     0
# Inns          0
# Opposition    0
# Ground        0
# Start Date    0
# dtype: int64

# %%
#Exploration Data Through Visualization
#Hist plot
plt.figure(figsize=(10,6))
sns.histplot(df['Runs'],bins=10,kde=True)
plt.title('Distribution of Runs Scored')
plt.show()

# %%
#Bar plot
plt.figure(figsize=(12,8))
ax=sns.barplot(data=df,x='Opposition',y='Runs',palette=['b','y','g','darkgreen','brown','k','lime','orange','maroon','darkgreen','r'])
countries=['Sri Lanka','Australia','Bangladesh','South Africa','Zimbambwe','New Zealand','Ireland','Netherlands','West Indies','Pakisthan','England']
plt.xticks(rotation=15)
ax.set_xticklabels(countries)
plt.show()
# Out:
# C:\Users\91861\AppData\Local\Temp\ipykernel_492\3670052621.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax=sns.barplot(data=df,x='Opposition',y='Runs',palette=['b','y','g','darkgreen','brown','k','lime','orange','maroon','darkgreen','r'])
# C:\Users\91861\AppData\Local\Temp\ipykernel_492\3670052621.py:6: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(countries)

# %%
#Heatmap of kohli statistics
plt.figure(figsize=(10,6))
sns.heatmap(data=df.corr(),annot=True,cmap='crest')
plt.title('Heatmap on Kohli stats')
plt.show()
